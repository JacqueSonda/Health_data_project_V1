# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
plt.style.use("ggplot")

# %%
df = pd.read_csv("heart_disease_uci.csv")

# %%
df.shape
# Out:
# (920, 16)

# %%
df.head(16)
# Out:
#     id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0    1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1    2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2    3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3    4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4    5   41  Female  Cleveland  atypical angina     130.0  204.0  False
# 5    6   56    Male  Cleveland  atypical angina     120.0  236.0  False
# 6    7   62  Female  Cleveland     asymptomatic     140.0  268.0  False
# 7    8   57  Female  Cleveland     asymptomatic     120.0  354.0  False
# 8    9   63    Male  Cleveland     asymptomatic     130.0  254.0  False
# 9   10   53    Male  Cleveland     asymptomatic     140.0  203.0   True
# 10  11   57    Male  Cleveland     asymptomatic     140.0  192.0  False
# 11  12   56  Female  Cleveland  atypical angina     140.0  294.0  False
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'sex', 'dataset', 'cp', 'trestbps', 'chol', 'fbs',
#        'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id            int64
# age           int64
# sex          object
# dataset      object
# cp           object
# trestbps    float64
# chol        float64
# fbs          object
# restecg      object
# thalch      float64
# exang        object
# oldpeak     float64
# slope        object
# ca          float64
# thal         object
# num           int64
# dtype: object

# %%
df.describe()
# Out:
#                id         age    trestbps        chol      thalch     oldpeak  \
# count  920.000000  920.000000  861.000000  890.000000  865.000000  858.000000
# mean   460.500000   53.510870  132.132404  199.130337  137.545665    0.878788
# std    265.725422    9.424685   19.066070  110.780810   25.926276    1.091226
# min      1.000000   28.000000    0.000000    0.000000   60.000000   -2.600000
# 25%    230.750000   47.000000  120.000000  175.000000  120.000000    0.000000
# 50%    460.500000   54.000000  130.000000  223.000000  140.000000    0.500000
# 75%    690.250000   60.000000  140.000000  268.000000  157.000000    1.500000
# max    920.000000   77.000000  200.000000  603.000000  202.000000    6.200000
#
#                ca         num
# count  309.000000  920.000000
# mean     0.676375    0.995652
# std      0.935653    1.142693
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    1.000000
# 75%      1.000000    2.000000
# ...

# %%
df.head(16)
# Out:
#     id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0    1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1    2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2    3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3    4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4    5   41  Female  Cleveland  atypical angina     130.0  204.0  False
# 5    6   56    Male  Cleveland  atypical angina     120.0  236.0  False
# 6    7   62  Female  Cleveland     asymptomatic     140.0  268.0  False
# 7    8   57  Female  Cleveland     asymptomatic     120.0  354.0  False
# 8    9   63    Male  Cleveland     asymptomatic     130.0  254.0  False
# 9   10   53    Male  Cleveland     asymptomatic     140.0  203.0   True
# 10  11   57    Male  Cleveland     asymptomatic     140.0  192.0  False
# 11  12   56  Female  Cleveland  atypical angina     140.0  294.0  False
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'sex', 'dataset', 'cp', 'trestbps', 'chol', 'fbs',
#        'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
df = df.rename(columns={"dataset":"city", "trestbps":"resting_blood_pressure", "thalch":"max_heartrate"})

# %%
df.head()
# Out:
#    id  age     sex       city               cp  resting_blood_pressure   chol  \
# 0   1   63    Male  Cleveland   typical angina                   145.0  233.0
# 1   2   67    Male  Cleveland     asymptomatic                   160.0  286.0
# 2   3   67    Male  Cleveland     asymptomatic                   120.0  229.0
# 3   4   37    Male  Cleveland      non-anginal                   130.0  250.0
# 4   5   41  Female  Cleveland  atypical angina                   130.0  204.0
#
#      fbs         restecg  max_heartrate  exang  oldpeak        slope   ca  \
# 0   True  lv hypertrophy          150.0  False      2.3  downsloping  0.0
# 1  False  lv hypertrophy          108.0   True      1.5         flat  3.0
# 2  False  lv hypertrophy          129.0   True      2.6         flat  2.0
# 3  False          normal          187.0  False      3.5  downsloping  0.0
# 4  False  lv hypertrophy          172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# ...

# %%
df.isna()
# Out:
#         id    age    sex   city     cp  resting_blood_pressure   chol    fbs  \
# 0    False  False  False  False  False                   False  False  False
# 1    False  False  False  False  False                   False  False  False
# 2    False  False  False  False  False                   False  False  False
# 3    False  False  False  False  False                   False  False  False
# 4    False  False  False  False  False                   False  False  False
# ..     ...    ...    ...    ...    ...                     ...    ...    ...
# 915  False  False  False  False  False                   False  False  False
# 916  False  False  False  False  False                    True  False  False
# 917  False  False  False  False  False                   False  False  False
# 918  False  False  False  False  False                    True  False  False
# 919  False  False  False  False  False                   False  False  False
#
# ...

# %%
df.isna().sum()
# Out:
# id                          0
# age                         0
# sex                         0
# city                        0
# cp                          0
# resting_blood_pressure     59
# chol                       30
# fbs                        90
# restecg                     2
# max_heartrate              55
# exang                      55
# oldpeak                    62
# slope                     309
# ca                        611
# thal                      486
# num                         0
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, age, sex, city, cp, resting_blood_pressure, chol, fbs, restecg, max_heartrate, exang, oldpeak, slope, ca, thal, num]
# Index: []

# %%
df.loc[df.duplicated(subset=["resting_blood_pressure"])].head(10)
# Out:
#     id  age     sex       city               cp  resting_blood_pressure  \
# 4    5   41  Female  Cleveland  atypical angina                   130.0
# 5    6   56    Male  Cleveland  atypical angina                   120.0
# 7    8   57  Female  Cleveland     asymptomatic                   120.0
# 8    9   63    Male  Cleveland     asymptomatic                   130.0
# 9   10   53    Male  Cleveland     asymptomatic                   140.0
# 10  11   57    Male  Cleveland     asymptomatic                   140.0
# 11  12   56  Female  Cleveland  atypical angina                   140.0
# 12  13   56    Male  Cleveland      non-anginal                   130.0
# 13  14   44    Male  Cleveland  atypical angina                   120.0
# 17  18   54    Male  Cleveland     asymptomatic                   140.0
#
#      chol    fbs         restecg  max_heartrate  exang  oldpeak        slope  \
# 4   204.0  False  lv hypertrophy          172.0  False      1.4    upsloping
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'sex', 'city', 'cp', 'resting_blood_pressure', 'chol',
#        'fbs', 'restecg', 'max_heartrate', 'exang', 'oldpeak', 'slope', 'ca',
#        'thal', 'num'],
#       dtype='object')

# %%
df = df.loc[~df.duplicated(subset=["resting_blood_pressure", "max_heartrate", "exang"])]

# %%
df
# Out:
#       id  age     sex           city               cp  resting_blood_pressure  \
# 0      1   63    Male      Cleveland   typical angina                   145.0
# 1      2   67    Male      Cleveland     asymptomatic                   160.0
# 2      3   67    Male      Cleveland     asymptomatic                   120.0
# 3      4   37    Male      Cleveland      non-anginal                   130.0
# 4      5   41  Female      Cleveland  atypical angina                   130.0
# ..   ...  ...     ...            ...              ...                     ...
# 912  913   53    Male  VA Long Beach     asymptomatic                   144.0
# 913  914   62    Male  VA Long Beach     asymptomatic                   158.0
# 914  915   46    Male  VA Long Beach     asymptomatic                   134.0
# 915  916   54  Female  VA Long Beach     asymptomatic                   127.0
# 919  920   62    Male  VA Long Beach  atypical angina                   120.0
#
# ...

# %%
df["resting_blood_pressure"].value_counts()
# Out:
# resting_blood_pressure
# 120.0    83
# 130.0    79
# 140.0    71
# 160.0    44
# 150.0    43
#          ..
# 164.0     1
# 101.0     1
# 174.0     1
# 192.0     1
# 127.0     1
# Name: count, Length: 61, dtype: int64

# %%
ax = df["resting_blood_pressure"].value_counts().head(20).plot(kind="bar", title="resting blood pressure per count")
ax.set_xlabel("resting_blood_pressure")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')
